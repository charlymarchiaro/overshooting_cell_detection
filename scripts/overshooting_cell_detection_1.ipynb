# %%
import os
import io
from zipfile import ZipFile
import requests
import pandas as pd
from datetime import datetime
from IPython.display import display, Markdown, Latex

import json

# %%
# Base URL de la api de Ingenier@
iga_api_base_url = "http://ing-acc-movil01.personal.corp/ingenier@/symfony/public/index.php/api"
job_src_data_folder = '..\\src_data\\traffica_insights_jobs'
post_proc_job_src_data_folder = '..\\src_data\\traffica_insights_post_processing_jobs'

job_src_file = 'traffica_insights_job_241.zip'
post_proc_job_src_file = 'traffica_insights_post_processing_job_89.zip'

# %% [markdown]
# ---
# # Traffica Insights Post Processing Job
#
# ---

# %%
def extract_zip(input_zip):
    input_zip=ZipFile(input_zip)
    return {name: input_zip.read(name) for name in input_zip.namelist()}

# Job
path = job_src_data_folder + '\\' + job_src_file
data = extract_zip(path)

job_data_df = pd.read_csv(io.BytesIO(next(iter(data.values()))), sep=';', decimal=',')


# Post-Processing Job
path = post_proc_job_src_data_folder + '\\' + post_proc_job_src_file
data = extract_zip(path)

stats_summary_df = None
stats_total_df = None
stats_filtered_df = None
post_proc_job_data_df = None
for key in data.keys():
    if key.startswith('stats'):
        stats_summary_df = pd.read_excel(io.BytesIO(data[key]), sheet_name='Resumen')
        stats_total_df = pd.read_excel(io.BytesIO(data[key]), sheet_name='Detalle (Total)')
        stats_filtered_df = pd.read_excel(io.BytesIO(data[key]), sheet_name='Detalle (Filtrado)')
    if key.startswith('data'):
        post_proc_job_data_df = pd.read_csv(io.BytesIO(data[key]))


# Display dataframes
display(Markdown('## ' + job_src_file))
display(Markdown('### Datos Crudos'))
display(job_data_df)
display(Markdown('## ' + post_proc_job_src_file))
display(Markdown('### Resumen'))
display(stats_summary_df)
display(Markdown('### Detalle (Total)'))
display(stats_total_df)
display(Markdown('### Detalle (Filtrado)'))
display(stats_filtered_df)
display(Markdown('### Datos Postprocesados'))
display(post_proc_job_data_df)
# Out:
# ## traffica_insights_job_241.zip
# ### Datos Crudos
#               ﻿Database              Event             Datetime  SiteName  \
# 0       PWTRAFFICATNES1  ENODEB ACTIVE RTT  2024-07-19 08:00:00  A07-S012
# 1       PWTRAFFICATNES1  ENODEB ACTIVE RTT  2024-07-19 08:00:01  A07-S012
# 2       PWTRAFFICATNES1  ENODEB ACTIVE RTT  2024-07-19 08:00:01  A07-S012
# 3       PWTRAFFICATNES1  ENODEB ACTIVE RTT  2024-07-19 08:00:02  A07-S012
# 4       PWTRAFFICATNES1  ENODEB ACTIVE RTT  2024-07-19 08:00:09  A07-S012
# ...                 ...                ...                  ...       ...
# 798038  PWTRAFFICATNES2  ENODEB ACTIVE RTT  2024-07-19 10:44:59  A07-S044
# 798039  PWTRAFFICATNES2  ENODEB ACTIVE RTT  2024-07-19 10:45:00  A07-S044
# 798040  PWTRAFFICATNES2  ENODEB ACTIVE RTT  2024-07-19 10:46:16  A07-S044
# 798041  PWTRAFFICATNES2  ENODEB ACTIVE RTT  2024-07-19 10:46:21  A07-S044
# 798042  PWTRAFFICATNES2  ENODEB ACTIVE RTT  2024-07-19 10:47:59  A07-S044
#
# ...

# %% [markdown]
# ---
# # Radios Aproximados de Sectores
#
# ---

# %%
payload = {
    "reportName": None,
    "siteNames": [],
    "filteringParams": {"SiteVisualizationData.SiteStatus": ["OA"]},
    "selectBySiteNames": False,
    "selectByFilteringParams": True
}

payload['reportName'] = "datos_radio_sector"
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)
with io.BytesIO(x.content) as fh:
    df_radio_sector_raw = pd.read_excel(fh, "Radios aproximados de sectores")

payload['reportName'] = "datos_outdoor"
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)
with io.BytesIO(x.content) as fh:
    df_outdoor_raw = pd.read_excel(fh, "Datos outdoor")

# %%
display(df_radio_sector_raw)
display(df_outdoor_raw)
# Out:
#        Código Sitio     EMG Estado Sitio Tipo Estación     Sector  \
# 0          A01-E133  XRCESE           OA         EasyM  XRCESEL1G
# 1          A01-E133  XRCESE           OA         EasyM  XRCESEL1H
# 2          A01-E133  XRCESE           OA         EasyM  XRCESEL1I
# 3          A01-E133  XRCESE           OA         EasyM  XRCESEM1G
# 4          A01-E133  XRCESE           OA         EasyM  XRCESEM1H
# ...             ...     ...          ...           ...        ...
# 165898       SPU990  SBBORI           OA         Macro  SBBORIU12
# 165899       SPU990  SBBORI           OA         Macro  SBBORIU13
# 165900       SPU990  SBBORI           OA         Macro  SBBORIV21
# 165901       SPU990  SBBORI           OA         Macro  SBBORIV22
# 165902       SPU990  SBBORI           OA         Macro  SBBORIV23
#
#               Tecnol./Banda Estado Sector  Radio Aprox. Sector [m]  \
# 0          LTE FDD_AWS_2225     Operativo                      618
# ...
